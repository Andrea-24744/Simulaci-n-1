# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrea-24744/Simulaci-n-1/blob/main/N%C3%BAmeros_Aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate
import pandas as pd

def generar(a, c, m, X_o):
    return (a * X_o + c) % m

a, c, m, X_o = 1, 27, 22, 3

muestra = [[i, X_o := generar(a, c, m, X_o), X_o / m] for i in range(50)]
df = pd.DataFrame(muestra, columns=["n", "X_n", "X_n/m"])
def estilo(valor):
    return 'color: green'

df_styled = df.style.applymap(estilo)
df_styled
# Out:
# <ipython-input-39-39f4339c7821>:14: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df_styled = df.style.applymap(estilo)
# <style type="text/css">
# ...
